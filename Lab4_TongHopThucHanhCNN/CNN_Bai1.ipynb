# %%
# Cell 1: Nạp thư viện cần thiết
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Cell 2: Đọc dataset CIFAR10
# # CIFAR10 gồm 60,000 ảnh màu 32x32, 10 nhãn

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()

# Tên các nhãn của CIFAR10
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

print("Shape X_train:", X_train.shape)   # (50000, 32, 32, 3)
print("Shape X_test :", X_test.shape)    # (10000, 32, 32, 3)
print("Shape y_train:", y_train.shape)
print("Shape y_test :", y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
# Shape X_train: (50000, 32, 32, 3)
# Shape X_test : (10000, 32, 32, 3)
# Shape y_train: (50000, 1)
# Shape y_test : (10000, 1)

# %% [markdown]
# # Cell 3: Hiển thị 10 ảnh đầu tiên để kiểm tra dữ liệu

# %%
plt.figure(figsize=(12, 2))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(X_train[i])
    plt.title(class_names[y_train[i][0]], fontsize=8)
    plt.axis('off')
plt.suptitle("Một số ảnh mẫu từ CIFAR10")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Cell 4: Tiền xử lý - Normalize pixel về [0, 1]
# # Ảnh gốc có pixel từ 0-255, chia cho 255 để đưa về 0-1
# # Mục đích: giúp model hội tụ nhanh hơn trong quá trình training

# %%
X_train = X_train / 255.0
X_test  = X_test  / 255.0

# Chuyển y từ shape (50000,1) về (50000,) cho phù hợp với loss function
y_train = y_train.flatten()
y_test  = y_test.flatten()

print("X_train sau normalize - min:", X_train.min(), "| max:", X_train.max())
print("y_train shape:", y_train.shape)
# Out:
# X_train sau normalize - min: 0.0 | max: 1.0
# y_train shape: (50000,)

# %% [markdown]
# # Cell 5: Xây dựng kiến trúc ANN
# # ANN không xử lý ảnh 2D trực tiếp -> cần Flatten để chuyển 32x32x3 = 3072 về 1 chiều

# %%
model = Sequential([
    # Flatten: chuyển ảnh 32x32x3 thành vector 3072 chiều
    Flatten(input_shape=(32, 32, 3)),

    # Hidden layer 1: 512 neurons, activation ReLU
    Dense(512, activation='relu'),
    Dropout(0.3),   # Dropout giảm overfitting, tắt ngẫu nhiên 30% neurons

    # Hidden layer 2: 256 neurons, activation ReLU
    Dense(256, activation='relu'),
    Dropout(0.3),

    # Output layer: 10 neurons (tương ứng 10 nhãn CIFAR10), activation softmax
    # Softmax trả về xác suất cho mỗi nhãn, tổng = 1
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,707,274 (6.51 MB)
#  Trainable params: 1,707,274 (6.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Cell 6: Compile model - thiết lập optimizer, loss function, metrics

# %%
model.compile(
    optimizer='adam',                            # Adam: optimizer phổ biến, tự điều chỉnh learning rate
    loss='sparse_categorical_crossentropy',      # Dùng khi nhãn là số nguyên (0,1,...,9)
    metrics=['accuracy']                         # Theo dõi độ chính xác trong quá trình training
)

print("Model đã được compile xong!")
# Out:
# Model đã được compile xong!

# %% [markdown]
# # Cell 7: Huấn luyện (Training) model
# # validation_split=0.1 -> tách 10% tập train làm tập validation để theo dõi

# %%
model_fit = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=20,      # Số lần duyệt qua toàn bộ tập train
    verbose=1       # Hiển thị tiến trình training
)

print("Training hoàn tất!")
# Out:
# Epoch 1/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 43s 29ms/step - accuracy: 0.2201 - loss: 2.0783 - val_accuracy: 0.2642 - val_loss: 1.9702
# Epoch 2/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 38s 27ms/step - accuracy: 0.2682 - loss: 1.9594 - val_accuracy: 0.2916 - val_loss: 1.8911
# Epoch 3/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 35s 25ms/step - accuracy: 0.2788 - loss: 1.9318 - val_accuracy: 0.3274 - val_loss: 1.8746
# Epoch 4/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.2793 - loss: 1.9275 - val_accuracy: 0.3040 - val_loss: 1.9025
# Epoch 5/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 43s 25ms/step - accuracy: 0.2876 - loss: 1.9079 - val_accuracy: 0.3138 - val_loss: 1.8730
# Epoch 6/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.2888 - loss: 1.9026 - val_accuracy: 0.3120 - val_loss: 1.8725
# Epoch 7/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 35s 25ms/step - accuracy: 0.3014 - loss: 1.8943 - val_accuracy: 0.3470 - val_loss: 1.8245
# Epoch 8/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 35s 25ms/step - accuracy: 0.2973 - loss: 1.8918 - val_accuracy: 0.3538 - val_loss: 1.8368
# Epoch 9/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.2984 - loss: 1.8855 - val_accuracy: 0.3486 - val_loss: 1.8204
# Epoch 10/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 35s 25ms/step - accuracy: 0.3051 - loss: 1.8789 - val_accuracy: 0.3534 - val_loss: 1.8192
# Epoch 11/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.3076 - loss: 1.8675 - val_accuracy: 0.3626 - val_loss: 1.8036
# Epoch 12/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.3113 - loss: 1.8596 - val_accuracy: 0.3292 - val_loss: 1.8267
# Epoch 13/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.3142 - loss: 1.8554 - val_accuracy: 0.3374 - val_loss: 1.8373
# Epoch 14/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.3157 - loss: 1.8551 - val_accuracy: 0.3532 - val_loss: 1.7982
# Epoch 15/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.3204 - loss: 1.8447 - val_accuracy: 0.3696 - val_loss: 1.7963
# Epoch 16/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.3199 - loss: 1.8451 - val_accuracy: 0.3686 - val_loss: 1.8093
# Epoch 17/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - accuracy: 0.3254 - loss: 1.8338 - val_accuracy: 0.3584 - val_loss: 1.7958
# Epoch 18/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 33s 23ms/step - accuracy: 0.3198 - loss: 1.8357 - val_accuracy: 0.3462 - val_loss: 1.8113
# Epoch 19/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - accuracy: 0.3217 - loss: 1.8290 - val_accuracy: 0.3326 - val_loss: 1.8325
# Epoch 20/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.3214 - loss: 1.8373 - val_accuracy: 0.3544 - val_loss: 1.7850
# Training hoàn tất!

# %% [markdown]
# # Cell 8: Vẽ biểu đồ để đánh giá quá trình training

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Biểu đồ Accuracy
axes[0].plot(model_fit.history['accuracy'],     label='train accuracy')
axes[0].plot(model_fit.history['val_accuracy'], label='val accuracy')
axes[0].set_title('Model Accuracy')
axes[0].set_ylabel('Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].legend(loc='lower right')

# Biểu đồ Loss
axes[1].plot(model_fit.history['loss'],     label='train loss')
axes[1].plot(model_fit.history['val_loss'], label='val loss')
axes[1].set_title('Model Loss')
axes[1].set_ylabel('Loss')
axes[1].set_xlabel('Epoch')
axes[1].legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Cell 9: Đánh giá model trên tập test (dữ liệu chưa thấy)

# %%
score = model.evaluate(X_test, y_test, verbose=2)
print('Test loss    :', score[0])
print('Test accuracy:', score[1])
# Out:
# 313/313 - 2s - 5ms/step - accuracy: 0.3656 - loss: 1.7755
# Test loss    : 1.7755054235458374
# Test accuracy: 0.36559998989105225

# %% [markdown]
# # Cell 10: Dự đoán nhãn cho một ảnh bất kỳ trong tập test

# %%
index = 0   # Thay số này để xem ảnh khác

# Cần thêm chiều batch: (32,32,3) -> (1,32,32,3)
img = np.expand_dims(X_test[index], axis=0)

# Dự đoán trả về mảng xác suất cho 10 nhãn
y_pred_proba = model.predict(img)
y_pred_label = np.argmax(y_pred_proba)   # Lấy nhãn có xác suất cao nhất

# Hiển thị kết quả
plt.imshow(X_test[index])
plt.title(f"Thực tế: {class_names[y_test[index]]} | Dự đoán: {class_names[y_pred_label]}")
plt.axis('off')
plt.show()

print(f"Xac suat du doan: {y_pred_proba[0][y_pred_label]*100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Xac suat du doan: 20.66%
